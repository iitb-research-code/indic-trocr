# %%
from transformers import VisionEncoderDecoderModel
from transformers import ViTFeatureExtractor, RobertaTokenizer, TrOCRProcessor
from transformers import VisionEncoderDecoderModel
from transformers import TrOCRProcessor
from PIL import Image
import matplotlib.pyplot as plt

# %%
encode = 'google/vit-base-patch16-224-in21k'
decode = 'flax-community/roberta-hindi'

# %%
feature_extractor=ViTFeatureExtractor.from_pretrained(encode)
tokenizer = RobertaTokenizer.from_pretrained(decode)
processor = TrOCRProcessor(feature_extractor=feature_extractor, tokenizer=tokenizer)
# Out:
# /Users/dishantpadalia/opt/miniconda3/envs/trocr/lib/python3.10/site-packages/transformers/models/trocr/processing_trocr.py:44: FutureWarning: The `feature_extractor` argument is deprecated and will be removed in v4.27, use `image_processor` instead.
#   warnings.warn(

# %%
model = VisionEncoderDecoderModel.from_pretrained("checkpoint-20600")

# %%
def preview(image_path):
    image = Image.open(image_path).convert("RGB")
    pixel_values = processor(image, return_tensors="pt").pixel_values
    generated_ids = model.generate(pixel_values)
    generated_text = processor.batch_decode(generated_ids, skip_special_tokens=True)[0]
    plt.imshow(image)
    print(generated_text)

# %%
image_path = "/Users/dishantpadalia/IITB/random/IIIT-HW-Hindi_v1/HindiSeg/test/11/1/1.jpg"
preview(image_path=image_path)
# Out:
# /Users/dishantpadalia/opt/miniconda3/envs/trocr/lib/python3.10/site-packages/transformers/generation/utils.py:1387: UserWarning: Neither `max_length` nor `max_new_tokens` has been set, `max_length` will default to 64 (`self.config.max_length`). Controlling `max_length` via the config is deprecated and `max_length` will be removed from the config in v5 of Transformers -- we recommend using `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# बबैठना

# %%
image_path = "/Users/dishantpadalia/IITB/random/IIIT-HW-Hindi_v1/HindiSeg/test/11/1/4.jpg"
preview(image_path=image_path)
# Out:
# जूहर

# %%
image_path = "/Users/dishantpadalia/IITB/random/IIIT-HW-Hindi_v1/HindiSeg/test/11/1/5.jpg"
preview(image_path=image_path)
# Out:
# खखून

# %%
image_path = "/Users/dishantpadalia/IITB/random/IIIT-HW-Hindi_v1/HindiSeg/test/11/1/6.jpg"
preview(image_path=image_path)
# Out:
# थकान

# %%
image_path = "/Users/dishantpadalia/IITB/random/IIIT-HW-Hindi_v1/HindiSeg/test/11/1/7.jpg"
preview(image_path=image_path)
# Out:
# ससुकार

# %%
image_path = "/Users/dishantpadalia/IITB/random/IIIT-HW-Hindi_v1/HindiSeg/test/11/1/8.jpg"
preview(image_path=image_path)
# Out:
# प्रसाहित

# %%
image_path = "/Users/dishantpadalia/IITB/random/IIIT-HW-Hindi_v1/HindiSeg/test/11/1/10.jpg"
preview(image_path=image_path)
# Out:
# अश्राद्धि

# %%
image_path = "/Users/dishantpadalia/IITB/random/IIIT-HW-Hindi_v1/HindiSeg/test/11/1/39.jpg"
preview(image_path=image_path)
# Out:
# छलछलांग।

# %%
image_path = "/Users/dishantpadalia/IITB/random/IIIT-HW-Hindi_v1/HindiSeg/test/9/144/10.jpg"
preview(image_path=image_path)
# Out:
# ठठंडक

# %%
image_path = "/Users/dishantpadalia/IITB/random/IIIT-HW-Hindi_v1/HindiSeg/test/9/128/32.jpg"
preview(image_path=image_path)
# Out:
# भभूलिएगा।

# %%
image_path = "/Users/dishantpadalia/IITB/random/IIIT-HW-Hindi_v1/HindiSeg/test/9/145/3.jpg"
preview(image_path=image_path)
# Out:
# इइंस्ट्री

# %%
image_path = "/Users/dishantpadalia/IITB/random/IIIT-HW-Hindi_v1/HindiSeg/test/9/123/13.jpg"
preview(image_path=image_path)
# Out:
# ररेलफेमी
